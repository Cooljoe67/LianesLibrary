# %% [markdown]
# <a href="https://colab.research.google.com/github/Cooljoe67/LianesLibrary/blob/main/SML_Day_14_Warmup_Nested_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.tree import DecisionTreeClassifier

# Load dataset (flipping labels so 1 = Malignant)
X, y = load_breast_cancer(return_X_y=True, as_frame=True)


model = DecisionTreeClassifier(random_state=42)

# Set up a hyperparameter grid
param_grid = {
    'max_depth': [2, 5, 9, 12],
    'min_samples_leaf': [2, 5, 9, 13]
}

# %% [markdown]
# ## Exercise 1: The "cheap" Way (Standard Grid Search)
# Set up a standard GridSearchCV using a 5-fold StratifiedKFold with shuffle=True and random_state=42. Fit it to the entire dataset and print the best params and recall score

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: The "expensive way" Way (Nested CV)
# To get an honest score, we need an Inner Loop to tune the hyperparameters, and a completely separate Outer Loop to test the winning model on fresh data.
#
# Use cross_val_score to wrap your grid_search inside a new 5-fold KFold. Print out the scores per grid search and the best params per fold

# %%
# Your code here

# %% [markdown]
# ## Bonus Exercise 3: Parameter Stability across different splits
#
# Write a for loop that runs 10 times.
#
# Inside the loop, create a new StratifiedKFold using the loop index (seed) as the random_state.
#
# Run a GridSearchCV and view the best params across each

# %%
# Your code here
